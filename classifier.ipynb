# %% [markdown]
# ## Обработчик резюме

# %%
import re
import os
import docx
import dateparser
import datetime

from pathlib import Path
from pymystem3 import Mystem
from pdfminer.high_level import extract_text

DATA_PATH = 'data/'

class Parser():
    def __init__(self, data_path):
        self.data_path = data_path
        self.resumes = {}
        self.final_json= {}

    # Функция для преобразования PDF-файла в текст
    def convert_pdf_to_text(self, path_to_pdf):
        with open(path_to_pdf, 'rb') as file:
            text = extract_text(file)
            return text
        
    # Функция для преобразования DOCX-файла в текст
    def convert_docx_to_text(self, path_to_docx):
        with open(path_to_docx, 'rb') as file:
            text = ""
            document = docx.Document(file)
            for paragraph in document.paragraphs:
                text += " " + paragraph.text
            return text
    
    # удаление лишних символов
    def preprocess_text(self, text):
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'[^a-zA-Z0-9а-яА-Я /._,@\-?=]', '', text)
        return text.strip()
    
    # Функция для получения данных из файлов в указанной директории
    def get_data(self):
        for i, file in enumerate(os.listdir(DATA_PATH)):
            if Path(file).suffix == '.pdf':
                resume = self.convert_pdf_to_text(DATA_PATH + file)
            elif Path(file).suffix == '.docx':
                resume = self.convert_docx_to_text(DATA_PATH + file)
            else:
                resume = False
            
            if resume:
                self.resumes[f'{DATA_PATH}{file}_{i}'] = self.preprocess_text(resume)

    # Функция для получения ФИО
    def get_mystem_info(self, text):
        m = Mystem()

        #TODO как ускорить?
        analyze = m.analyze(text)
        # print(analyze)

        fio = {
            'last_name': '',
            'first_name': '',
            'middle_name': ''
        }

        city = ''

        for word in analyze:
            try:
                analysis = word['analysis'][0]
            except (KeyError, IndexError):
                continue

            if 'имя' in analysis.get('gr', '') and not fio['first_name']:
                fio['first_name'] = word['text'].capitalize()
            elif 'фам' in analysis.get('gr', '') and not fio['last_name']:
                fio['last_name'] = word['text'].capitalize()
            elif 'отч' in analysis.get('gr', '') and not fio['middle_name']:
                fio['middle_name'] = word['text'].capitalize()
            elif 'гео' in analysis.get('gr', '') and city == '':
                city = word['text'].capitalize()

        fio = ' '.join(fio.values()).strip()

        return fio, city
    
    def get_birthday(self, text):
        birthday = re.search(r'(0?[1-9]|[12][0-9]|3[01]) (янв(?:аря)?|фев(?:раля)?|мар(?:та)?|апр(?:еля)?|мая|июн(?:я)?|июл(?:я)?|авг(?:уста)?|сен(?:тября)?|окт(?:ября)?|ноя(?:бря)?|дек(?:абря)?) ([12][0-9][0-9][0-9])', text.lower())

        if birthday:
            return dateparser.parse(birthday.group(), languages=['ru'])
        else:
            return None
        
    def get_age(self, birth_date):
        now = datetime.datetime.now()
        age = now.year - birth_date.year
        if now.month < birth_date.month or (now.month == birth_date.month and now.day < birth_date.day):
            age -= 1
        return age


    # Функция для получения почты
    def get_mail(self, text):
        mail = re.search(r'[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}', text)

        if mail:
            return mail.group()
        else:
            return None

    # Функция для получения номера телефона (+7/7/8 - РФ номера)
    def get_phone_number(self, text):
        phone_number = re.search(r' (\+7|8|7).*?(\d{3}).*?(\d{3}).*?(\d{2}).*?(\d{2})', text)
        if phone_number:
            return phone_number.group().replace(' ', '').replace('-','')
        else:
            return None
    
    # Функция для поиска полезных ссылок
    def get_links(self, text):
        link = re.findall(r'\b(?:http?|www\.)\S+\b', text)
        if link:
            return link
        else:
            return None


    def fill_final_json(self):

        for file, info in self.resumes.items():
            print(file)

            fio, city = self.get_mystem_info(info)
            birthday_date = self.get_birthday(info)

            self.final_json[file] = {}
            self.final_json[file]['fio'] = fio
            self.final_json[file]['date'] = birthday_date.strftime("%d.%m.%Y")
            self.final_json[file]['city'] = city
            self.final_json[file]['age'] = self.get_age(birthday_date)
            self.final_json[file]['email'] = self.get_mail(info)
            self.final_json[file]['phone_number'] = self.get_phone_number(info)
            self.final_json[file]['links'] = self.get_links(info)

        
            

parser = Parser(DATA_PATH)
parser.get_data()
# parser.resumes
parser.fill_final_json()
parser.final_json
# Out:
# data/Чистяков Максим Владимирович 22.47.34.pdf_1
# data/Нафгутдинов Рафаэль.docx_2
# data/Резюме_Козлова Ирина.pdf_3
# data/Нафгутдинов Рафаэль 15.26.39.pdf_4
# data/Резюме_Козлова Ирина.docx_5
# data/Юдин Константин Александрович.pdf_6
# data/Резюме_Data_Engineer_Максим_Евгеньевич_Чувакин_от_11_09_2023_13.pdf_7
# {'data/Чистяков Максим Владимирович 22.47.34.pdf_1': {'fio': 'Чистяков Максим Владимирович',
#   'date': '15.07.1997',
#   'city': 'Москва',
#   'age': 26,
#   'email': 'max150797@yandex.ru',
#   'phone_number': '79160525669',
#   'links': ['https//github.com/max150797',
#    'https//www.kaggle.com/max150797/competitions?tab=active']},
#  'data/Нафгутдинов Рафаэль.docx_2': {'fio': 'Нафгутдинов Рафаэль',
#   'date': '14.11.1995',
#   'city': 'Москва',
#   'age': 28,
#   'email': 'max150797@yandex.ru',
#   'phone_number': '79160525669',
#   'links': None},
#  'data/Резюме_Козлова Ирина.pdf_3': {'fio': 'Козлова Ирина Алексеевна',
#   'date': '23.10.1996',
#   'city': 'Москва',
#   'age': 27,
#   'email': 'ira_kozlova_00@mail.ru',
#   'phone_number': '79175617480',
#   'links': None},
#  'data/Нафгутдинов Рафаэль 15.26.39.pdf_4': {'fio': 'Нафгутдинов Рафаэль',
#   'date': '14.11.1995',
#   'city': 'Москва',
#   'age': 28,
#   'email': 'max150797@yandex.ru',
#   'phone_number': '79160525669',
#   'links': None},
#  'data/Резюме_Козлова Ирина.docx_5': {'fio': 'Козлова Ирина Алексеевна',
#   'date': '23.10.1996',
#   'city': 'Москва',
#   'age': 27,
#   'email': 'ira_kozlova_00@mail.ru',
#   'phone_number': '79175617480',
#   'links': None},
#  'data/Юдин Константин Александрович.pdf_6': {'fio': 'Юдин Константин Александрович',
#   'date': '11.08.1996',
#   'city': 'Москва',
#   'age': 27,
#   'email': 'dev.kyudin@gmail.com',
#   'phone_number': '79773006143',
#   'links': ['https//t.me/mvirtual', 'www.mts.ru', 'www.comindware.com']},
#  'data/Резюме_Data_Engineer_Максим_Евгеньевич_Чувакин_от_11_09_2023_13.pdf_7': {'fio': 'Чувакин Максим Евгеньевич',
#   'date': '24.10.1997',
#   'city': 'Москва',
#   'age': 26,
#   'email': 'mo.546@yandex.ru',
ом, вихревым смесителем и другими лабораторными приборами  проведение качественных анализов в соответствии c методическими рекомендациями в аккредитованной лаборатории острых и хронических токсикологических испытаний с использованием высших растений, биотестирование с использованием гидробионтов, биотестирование на бактериях по биолюминесценции  метод оценки функционального разнообразия микробных сообществ  определение микробной биомассы газохроматографическим методом  приготовление питательных растворов и сред  умение работать с биологическими объектами в стерильных условиях  посевы культуры на чашки Петри и на косяки  выполнение анализов по заданию руководителя лаборатории  методы статистической обработки  составление и публикация научных статей. 1. Период работы конец января 2021  апрель 2021 Должность стажер в лаборатории Организация ООО ЭКОСТАНДАРТ Технические решения Лаборатория физико-химическая Должностные обязанности ведение лабораторных журналов, учет расхода реактивов и государственных стандартных образцов, работа с нормативной документацией. 2. Период работы апрель 2021  апрель 2022 Должность специалист по охране труда Организация АО ЦНИИ ЭИСУ Должностные обязанности организация сбора и обработки информации по вопросам состояния условий и охраны труда, проведение инструктажей, подготовка отчетной документации, подбор и предоставление необходимой документации и информации по вопросам паспортизации образующихся отходов, взаимодействие с организациями, осуществляющими оценку аккредитованными классов лабораториями, выполнение работ по заданию руководителя Службы охраны труда. производства опасности отходов 3. Период работы март 2022  июнь 2022 Должность ответственный исполнитель по гранту РНФ  22-24-00666 Меланинсодержащие грибы техногенно нарушенных почв индикация химического загрязнения и биотехнологический потенциал Организация МГУ имени М.В. Ломоносова, ф-т Почвоведения, Кафедра земельных ресурсов и оценки почв. 2 Должностные обязанности Оценка структурного и функционального разнообразия микробиоты в почвах, загрязненных тяжелыми металлами, обработка экспериментальных данных в программах Statistica, Excel. Подготовка статьи. Образование Учебное заведение МГУ им. М.В. Ломоносова Год окончания 2020 Факультет Биологический Специальность Экология и природопользование, бакалавр Форма обучения очная Учебное заведение Московская школа прикладного управления и делового администрирования Год окончания 2021 Программа Организация и мониторинг сист ...
#  'data/Нафгутдинов Рафаэль 15.26.39.pdf_4': 'Нафгутдинов Рафаэль Мужчина, 27 лет, родился 14 ноября 1995 7 916 0525669  предпочитаемый способ связи  tg @rafferti_95 max150797@yandex.ru Проживает Москва Гражданство Россия, есть разрешение на работу Россия Не готов к переезду, не готов к командировкам Желаемая должность и зарплата Аналитик данных Специализации  Дата-сайентист  Аналитик Занятость полная занятость График работы полный день Желательное время в пути до работы не имеет значения Опыт работы  3 года 2 месяца Май 2023  настоящее время 6 месяцев SkillFactory - студент Data Scientist Проект 1. Анализ резюме на HeadHunter pandas, numpy, matplotlib - предобработка данных обработка выбросов и пустых значений - исследовательский анализ данных выявление закономерностей в данных и построение информативных графиков Проект 2. Анализ вакансий на HeadHunter SQL, Python - выгрузка данных, используя SQL для дальнейшего анализа данных - использование сложных оптимизированных запросов Проект 3. Статистические тесты - генерация и проверка гипотез, определение статистической значимости и оценка взаимосвязей между переменными - представление результатов в виде графиков, таблиц, статистических выводов и аргументированных заключений можешь тут прикрепить ссылку на kaggle и github Сентябрь 2020  настоящее время 3 года 2 месяца Ингеосервис Услуги для бизнеса  Консалтинговые услуги Геолог 1-й категории Анализ и предобработка геологических данных pandas Построение трехмерных модел
системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Телекоммуникации, связь  Мобильная связь Старший инженер-программист - Сократил время выдачи облачных ресурсов компании с 5 дней до 15 минут за счет разработки системы управления ИТ-инфраструктурой и изменения внутренних бизнес-процессов - Разработал и внедрил подсистему ITSM, которая помогла инфраструктурной команде существенно сэкономить на покупке оборудования уже в первый месяц эксплуатации Разработка на C Blazor, API, SOA Code review Unit и интеграционное тестирование Ноябрь 2018  Апрель 2020 1 год 6 месяцев MindScan Москва, mindscan.ru Информационные технологии, системная интеграция, интернет  Разработка программного обеспечения Инженер-программист - Ускорил работу системы полнотекстового поиска так, что время выполнения сложных запросов с выборкой в 100 млн. записей уменьшилось до 1,3 с. - Снижена скорость реагирования МЧС на ЧС наводнение, пожар, задымление за счет интеграции основного продукта компании с Департаментом информационных технологий города Москвы. Разработка на языке C MSA, API, SOA Написание и оптимизация SQL-запросов Code review Unit и интеграционное тестирование Июль 2017  Ноябрь 2018 1 год 5 месяцев Comindware Москва, www.comindware.com/ Информационные технологии, системная интеграция, интернет  Разработка программного обеспечения  Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Младший инженер-программист - Ускорил время работы workflow-движка на 30  за счет оптимизаций кода и хранения данных. - Реализовал фронэнд и бэкэнд части системы дашбордов, которая позволяет клиентам создавать десятки кастомных дашбордов без написания кода - Анализ ТЗ, - Fullstack разработка архитектура модулей системы, написание необходимых сервисов, разработка API и Web-интерфейсов - Unit и интеграционное тестирование - Написание сопроводительной документации - Обновление и поддержка существующих модулей системы - Обновление документации и тестов - Исправление возникающих ...
#  'data/Резюме_Data_Engineer_Максим_Евгеньевич_Чувакин_от_11_09_2023_13.pdf_7': 'Чувакин Максим Евгеньевич Мужчина, 25 лет, родился 24 октября 1997 7 915 0129908 mo.546@yandex.ru  предпочитаемый способ связи Проживает Москва, м. Говорово Гражданство Россия, есть разрешение на работу Россия Не готов к переезду, готов к командировкам Желаемая должность и зарплата Data Engineer Специализации  Программист, разработчик Занятость полная занятость График работы полный день, гибкий график, удаленная работа Желательное время в пути до работы не более полутора часов Опыт работы  5 лет Октябрь 2018  настоящее время 5 лет Рамакс Системз Консультант SAP Разработка процессов загрузки в хранилище данных. Расширение модели данных хранилища. Образование Бакалавр 2019 Финансовый университет при Правительстве Российской Федерации, Москва Прикладная математика и информационные технологии, Бизнес-информатика Повышение квалификации, курсы 2021 2019 SAP Certified Application Associate - Reporting, Modeling and Data Acquisition with SAP BW/4HANA 2.x SAP SE SAP Certified Application Associate - Data Integration with SAP Data Services 4.2 SAP SE Ключевые навыки Знание языков Русский  Родной Английский  B2  Средне-продвинутый Опыт вождения Резюме обновлено 11 сентября 2023 в 1254 Права категории B Дополнительная информация Обо мне Имеются Диплом 3 степени - Конкурс Мобильный прорыв - конкурс среди разработчиков мобильных приложений для B2B на базе платформы ОПТИМУМ ЦИМПП Сертификат ОПТИМУМ ЦИМПП - Курс по работе с программным комплексом ОПТИМУМ ЦИМПП Сертификат КонсультантПлюс - Основной курс обучения работе с системой КонсультантПлюс Чувакин Максим  Резюме обновлено 11 сентября 2023 в 1254'}

# %%
import datetime

# Получение текущей даты
now = datetime.datetime.now()

# Пример данных в вашем датафрейме
birth_date = datetime.datetime(1990, 1, 1)

# Вычисление количества полных лет
age = now.year - birth_date.year
if now.month < birth_date.month or (now.month == birth_date.month and now.day < birth_date.day):
    age -= 1

print(age)
# Out:
# 34
